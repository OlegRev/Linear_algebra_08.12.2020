# %%
import numpy as np
from numpy.linalg import norm

# %% [markdown]
# ## Практическое задание

# %% [markdown]
# ### __1.__ Исследовать на линейную зависимость:
# $$f_{1}(x)=e^{x}, f_{2}(x)=1, f_{3}(x)=x+1, f_{4}(x)=x-e^{x}.$$

# %% [markdown]
# Попробуем выразить хотябы один объект через другие.
#     $f_{1}(x) = e^{x},\\ f_{2}(x) = 1,\\ f_{3}(x) = \ln{f_1(x)} + f_2(x),\\ f_4(x) = \ln{f_1(x)} - f_1(x)$
#
# Система линейно зависима так как 3 и 4 объекты можно выразить через первые 2-а

# %% [markdown]
# ### __2.__ Исследовать на линейную зависимость:
# $$f_{1}(x)=2, f_{2}(x)=x, f_{3}(x)=x^{2}, f_{4}(x)=(x+1)^{2}.$$

# %% [markdown]
# Попробуем выразить хотябы один объект через другие.
# $f_{1}(x)=2,\\ f_{2}(x)=x,\\ f_{3}(x) = (f_{2}(x))^{f_{1}(x)},\\ f_{4}(x) = \big(f_{2}(x) + \frac{f_{1}(x)}{f_{1}(x)}\big)^{f_{1}(x)}$
#
# Система линейно зависима так как 3 и 4 объекты можно выразить через первые 2-а

# %% [markdown]
# ### __3.__ Найти координаты вектора $x = (2, 3, 5)\in \mathbb{R}^{3}$ в базисе $b_{1}=(0, 0, 10)$, $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$.

# %% [markdown]
# #### $\quad x = (0.5\cdot b1,1\cdot b2,3\cdot b3)=
# (\frac{1}{2}\cdot b_1, b_2, 3\cdot b_3)$

# %% [markdown]
# ### __4.__ Найти координаты вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$:
# #### а) в базисе $1, x, x^{2}$;
# #### б) в базисе $x^{2}, x-1, 1$.

# %% [markdown]
# #### Координаты вектора:
# $3x^2-2x + 2 \to (3x^2, -2x, 2)$
# #### Базис а:
# $(1, x, x^2) \to a_1 =(1, 0, 0), a_2 = (0, x, 0), a_3 = (0, 0, x^2)\\
# (3\cdot a_3, -2\cdot a_2, 2\cdot a_1)$
# #### Базис б:
# $(x^2, x-1, 1) \to b_1 =(x^2, 0, 0), b_2=(0, x-1, 0), b_3=(0, 0, 1)\\
# (3\cdot b_1, -2\cdot b_2, 0)
# $

# %% [markdown]
# ### __5.__ Установить, является ли линейным подпространством:
#     а) совокупность всех векторов трехмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;
#
# б) все векторы, являющиеся линейными комбинациями данных векторов $\{u_{1}, u_{2}, ..., u_{n}\}$.

# %% [markdown]
# a) Проведя проверку по приведенному утверждению, мы увидим, что
#
# $(0, a, b)+(0, c, d) = (0, a+c, b+d),\\
# \alpha\cdot (0, a, b) = (0, \alpha a, \alpha b)\\\quad\\
# (a, 0, b)+(c, 0, d) = (a+c, 0, b+d),\\
# \alpha\cdot (a, 0, b) = (\alpha a, 0, \alpha b)\\\quad\\
# (0, 0, b)+(0, 0, d) = (0, 0, b+d),\\
# \alpha\cdot (0, 0, b) = (0, 0, \alpha b)\\\quad\\
# (0, a, b)+(c, 0, d) = (c, a, b+d),\\
# $
#
#
# Полученные векторы также принадлежат указанному в задании множеству всех векторов вида $(0, a, b), (a, 0, b), (0, 0, b)$, $(0, a, b)+(c, 0, d)=(c, a, b+d)$ не принадлежит пространству где по крайней мере одна из первых координат равна нулю, то есть данное множество НЕ является подпространством линейного пространства $\mathbb{R}^{3}$.

# %% [markdown]
# ## Практическое задание

# %% [markdown]
# ### __1.__ Найти скалярное произведение векторов $x, y \in \mathbb{R}$:<br>
# а) $x=(0,-3, 6),~y=(-4, 7, 9);$<br>
# б) $x=(7, -4, 0, 1),~y=(-3, 1, 11, 2).$

# %%
xa = [0, -3, 6]
ya = [-4, 7, 9]
a = xa[0]*ya[0]+xa[1]*ya[1]+xa[2]*ya[2]
xb = [7, -4, 0, 1]
yb = [-3, 1, 11, 2]
b = xb[0]*yb[0] + xb[1]*yb[1] + xb[2]*yb[2] + xb[3]*yb[3]


xa1 = np.array(xa)
ya1 = np.array(ya)
xb1 = np.array(xb)
yb1 = np.array(yb)

print(f'Скалярное произведение посчитаное в ручную:\n\tа): {a}\n\tб):{b}\n\n'
      f'Скалярное произведение numpy.dot(x, y) a) 𝑥=(0,−3,6), 𝑦=(−4,7,9):\n'
      f'\t{np.dot(xa1, ya1)}\n'
      f'Скалярное произведение numpy.dot(x, y) б) 𝑥=(7,−4,0,1), 𝑦=(−3,1,11,2):\n'
      f'\t{np.dot(xb1, yb1)}')
# Out:
# Скалярное произведение посчитаное в ручную:
# 	а): 33
# 	б):-23
#
# Скалярное произведение numpy.dot(x, y) a) 𝑥=(0,−3,6), 𝑦=(−4,7,9):
# 	33
# Скалярное произведение numpy.dot(x, y) б) 𝑥=(7,−4,0,1), 𝑦=(−3,1,11,2):
# 	-23

# %% [markdown]
# ### __2.__ Найти нормы векторов $(4, 2, 4)$ и $(12, 3, 4)$ и угол между ними.

# %%
x = [4,2,4]
y = [12,3,4]

l1x = abs(x[0]) + abs(x[1]) + abs(x[2])
l1y = abs(y[0]) + abs(y[1]) + abs(y[2])

l2x = np.sqrt(x[0]**2 + x[1]**2 + x[2]**2)
l2y = np.sqrt(y[0]**2 + y[1]**2 + y[2]**2)
cos_f = (x[0]*y[0]+x[1]*y[1]+x[2]*y[2])/(l2x*l2y)
x1=np.array([4,2,4])
y1=np.array([12,3,4])
print(f'Норма вектора (4,2,4) l1 ={l1x}\n'
      f'Норма вектора (12,3,4) l1 ={l1y}\n'
      f'Норма вектора (4,2,4) l2 ={l2x}\n'
      f'Норма вектора (12,3,4) l2 ={l2y}\n'
      f'cos_f между векторами  (4,2,4) и (12,3,4) : {cos_f}\n'
      f'угол между векторами равен {np.arccos(cos_f)}')
print(f'l1 норма вектора  (4,2,4):\n{norm(x1, ord=1)}\n'
      f'l1 норма вектора (12,3,4) :\n{norm(y1, ord=1)}\n'
      f'l2 норма вектора  (4,2,4):\n{norm(x1, ord=2)}\n'
      f'l2 норма вектора (12,3,4) :\n{norm(y1, ord=2)}')
# Out:
# Норма вектора (4,2,4) l1 =10
# Норма вектора (12,3,4) l1 =19
# Норма вектора (4,2,4) l2 =6.0
# Норма вектора (12,3,4) l2 =13.0
# cos_f между векторами  (4,2,4) и (12,3,4) : 0.8974358974358975
# угол между векторами равен 0.45687400353266105
# l1 норма вектора  (4,2,4):
# 10.0
# l1 норма вектора (12,3,4) :
# 19.0
# l2 норма вектора  (4,2,4):
# 6.0
# l2 норма вектора (12,3,4) :
# 13.0

# %% [markdown]
# ### __3.__ Будет ли линейное пространство евклидовым, если за скалярное произведение принять:
#     а) произведение длин векторов;
#     б) утроенное обычное скалярное произведение векторов?

# %% [markdown]
# __4.__ Какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве $\mathbb{R}^{3}$:<br>
# а) $(1,0,0),(0,0,1);$ <br>
# б) $(1/\sqrt{2},-1/\sqrt{2},0),(1/\sqrt{2},1/\sqrt{2},0), (0,0,1);$<br>
# в) $(1/2, -1/2, 0), (0, 1/2, 1/2), (0,0,1);$<br>
# г) $(1,0,0),(0,1,0),(0,0,1)?$

# %% [markdown]
# г)

# %%
a = np.array([1/(2)**0.5,-1/(2)**0.5,0])
b = np.array([1/(2)**0.5,1/(2)**0.5,0])
c = np.array([0,0,1])

print(np.dot(a, a),np.dot(b, b),np.dot(c, c))
print(f'(a,b){np.dot(a,b)}\t(a,c){np.dot(a, c)}\t(c, b){np.dot(c, b)}')
# Out:
# 0.9999999999999998 0.9999999999999998 1
# (a,b)0.0	(a,c)0.0	(c, b)0.0
